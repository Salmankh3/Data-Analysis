# %% [markdown]
# # OLYMPIC EVENTS DATA ANALYSIS & VISUALIZATIONS

# %% [markdown]
# ---------------

# %% [markdown]
# <b>LOADING DATASET</b>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("olympic_events.csv", encoding="ISO-8859-1")
data.head()
# Out:
#        id     sport    discipline                       name     sex  \
# 0  701492  aquatics    backstroke    Women's 100m Backstroke  female
# 1  305278  aquatics    backstroke    Women's 200m Backstroke  female
# 2  708010  aquatics    backstroke      Men's 100m Backstroke    male
# 3  729643  aquatics    backstroke      Men's 200m Backstroke    male
# 4  567019  aquatics  breaststroke  Women's 100m Breaststroke  female
#
#                      venues
# 0  Olympic Aquatics Stadium
# 1  Olympic Aquatics Stadium
# 2  Olympic Aquatics Stadium
# 3  Olympic Aquatics Stadium
# 4  Olympic Aquatics Stadium

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 6 columns):
# id            306 non-null int64
# sport         306 non-null object
# discipline    306 non-null object
# name          306 non-null object
# sex           306 non-null object
# venues        306 non-null object
# dtypes: int64(1), object(5)
# memory usage: 14.4+ KB

# %%
data.isna().sum()
# Out:
# id            0
# sport         0
# discipline    0
# name          0
# sex           0
# venues        0
# dtype: int64

# %%
data["id"].unique().size
# Out:
# 306

# %% [markdown]
# ----------

# %% [markdown]
# <b>ANALYZING ATTRIBUTES</b>

# %% [markdown]
# <b>Gender / Sex</b>

# %%
# COUNTS
data["sex"].value_counts()
# Out:
# male      161
# female    136
# mixed       9
# Name: sex, dtype: int64

# %%
# GENDER / SEX VISUALS

fig = plt.figure(figsize=(13,6))

fig.add_subplot(1,2,1)
plt.pie(data["sex"].value_counts(), autopct="%1.2f%%", labels=data["sex"].value_counts().index, startangle=180)
plt.title("GENDER COUNT PIE CHART")

fig.add_subplot(1,2,2)
sns.countplot(data["sex"])
plt.title("GENDER COUNT BAR CHART")

plt.show()

# %% [markdown]
# <b>Conclusions:</b>
# The highest occurence is of the male gender in the olympics event i.e. 52.6%, while female genders are 44.4%. There is also a mixed gender (paired participation) which seems to be only approximately 3%.

# %% [markdown]
# <b>Sport</b>

# %%
# COUNTS
data["sport"].value_counts()
# Out:
# athletics            47
# aquatics             46
# cycling              18
# wrestling            18
# gymnastics           18
# canoe                16
# shooting             15
# weightlifting        15
# judo                 14
# rowing               14
# boxing               13
# sailing              10
# fencing              10
# taekwondo             8
# equestrian            6
# tennis                5
# badminton             5
# archery               4
# volleyball            4
# table tennis          4
# rugby sevens          2
# handball              2
# golf                  2
# triathlon             2
# basketball            2
# hockey                2
# modern pentathlon     2
# football              2
# Name: sport, dtype: int64

# %%
plt.figure(figsize=(13,10))

sns.countplot(y = data["sport"], orient="v", color="lightblue")
plt.title("SPORT COUNT BAR CHART")

plt.show()

# %% [markdown]
# <b>Conclusions:</b>
# Athletics came up with the highest occurence in our dataset (47 counts), while basketball, football, golf, hockey, handball, m.pentathlon, rugby, and triathlon have the least count (only 1).

# %% [markdown]
# <b>Discipline</b>

# %%
# COUNTS
data["discipline"].value_counts()
# Out:
# freestyle                26
# track                    24
# shooting                 15
# weightlifting            15
# rowing                   14
# artistic gymnastics      14
# judo                     14
# boxing                   13
# canoe sprint             12
# cycling track            10
# sailing                  10
# diving                    8
# jumps                     8
# throws                    8
# taekwondo                 8
# medley                    6
# individual                6
# greco roman               6
# tennis                    5
# badminton                 5
# road                      5
# canoe slalom              4
# team                      4
# butterfly                 4
# cycling road              4
# breaststroke              4
# backstroke                4
# table tennis              4
# archery                   4
# volleyball                2
# hockey                    2
# golf                      2
# combined                  2
# rugby sevens              2
# jumping                   2
# trampoline gymnastics     2
# rhythmic gymnastics       2
# football                  2
# beach volleyball          2
# eventing                  2
# marathon swimming         2
# triathlon                 2
# basketball                2
# water polo                2
# synchronised swimming     2
# handball                  2
# cycling mountain bike     2
# cycling bmx               2
# dressage                  2
# modern pentathlon         2
# Name: discipline, dtype: int64

# %%
plt.figure(figsize=(12,12))
sns.countplot(y=data["discipline"], color="lightgreen")
plt.title("DISCIPLINE COUNT BAR CHART")

plt.show()

# %% [markdown]
# <b>Conclusion:</b>
# In the Discipline attribute, there is the most occurence of "freestyle" (appeared 26 times @ 8.50%).

# %% [markdown]
# <b>Names</b>

# %%
data["name"].value_counts()
# Out:
# Men                                  11
# Women                                11
# Men's Team                            3
# Men's Singles                         3
# Women's Singles                       3
# Women's Team                          3
# Men's Doubles                         2
# Women's Doubles                       2
# Mixed Doubles                         2
# Men's Individual                      2
# Women's Individual                    2
# Women -49kg                           1
# Women's 20km Walk                     1
# Men's 10,000m                         1
# Men's 94kg                            1
# Skeet Men                             1
# Women's Individual All-Around         1
# Men's Light Heavy (81kg)              1
# Men's ÌäpÌ©e Team                     1
# Women's 5000m                         1
# Kayak (K1) Women                      1
# Men's Individual All-Around           1
# Men +80kg                             1
# Men's 20km Walk                       1
# Women's Road Race                     1
# Lightweight Women's Double Sculls     1
# Women -57kg                           1
# Women's 50m Freestyle                 1
# Women's Freestyle 48 kg               1
# Nacra 17 Mixed                        1
#                                      ..
# Women's Cross-country                 1
# Women's 53kg                          1
# Men's Heavy (91kg)                    1
# Men's 5000m                           1
# Women's 400m Individual Medley        1
# Men -66 kg                            1
# Men's 100m Backstroke                 1
# Men's +105kg                          1
# Women's 10m Platform                  1
# Women's 200m                          1
# Men's Canoe Single 1000m              1
# Women's Middle (69-75kg)              1
# Men's Synchronised 10m Platform       1
# Skeet Women                           1
# Women's ÌäpÌ©e Team                   1
# Women's Team Sprint                   1
# Men's Quadruple Sculls                1
# 49er FX Women                         1
# Men's 400m Individual Medley          1
# Men -60 kg                            1
# Men's Middle (75kg)                   1
# Women's Quadruple Sculls              1
# Men's 100m Breaststroke               1
# Women's 75kg                          1
# Men's Floor Exercise                  1
# Duets                                 1
# Men's Single Sculls                   1
# Women's Sabre Team                    1
# Women's 3000m Steeplechase            1
# Men's Discus Throw                    1
# Name: name, Length: 273, dtype: int64

# %%
plt.figure(figsize=(12,70))
sns.countplot(y=data["name"], color="gray")
plt.title("EVENT NAMES COUNT BAR CHART")

plt.show()

# %% [markdown]
# <b>Conclusion:</b>
# The "Men" and "Women" category of the event names are having the highest occurence in the dataset appearing 11 times each of them.

# %%
data["venues"].value_counts()
# Out:
# Olympic Stadium                                                                                                         42
# Olympic Aquatics Stadium                                                                                                32
# Carioca Arena 2                                                                                                         32
# Lagoa Stadium                                                                                                           26
# Carioca Arena 3                                                                                                         18
# Rio Olympic Arena                                                                                                       18
# Olympic Shooting Centre                                                                                                 15
# Riocentro - Pavilion 2                                                                                                  15
# Riocentro - Pavilion 6                                                                                                  13
# Maria Lenk Aquatics Centre                                                                                              10
# Marina da GlÌ_ria                                                                                                       10
# Rio Olympic Velodrome                                                                                                   10
# Fort Copacabana                                                                                                          6
# SambÌ_dromo                                                                                                              6
# Olympic Equestrian Centre                                                                                                6
# Pontal                                                                                                                   5
# Olympic Tennis Centre                                                                                                    5
# Riocentro - Pavilion 4                                                                                                   5
# Riocentro - Pavilion 3                                                                                                   4
# Whitewater Stadium                                                                                                       4
# Deodoro Aquatics Centre, Deodoro Stadium, Youth Arena                                                                    2
# Deodoro Stadium                                                                                                          2
# MaracanÌ£zinho                                                                                                           2
# Olympic Golf Course                                                                                                      2
# Future Arena                                                                                                             2
# Olympic Hockey Centre                                                                                                    2
# Mountain Bike Centre                                                                                                     2
# MineirÌ£o, Olympic Stadium, Fonte Nova Arena, AmazÌ«nia Arena, Corinthians Arena, ManÌ© Garrincha Stadium, MaracanÌ£     2
# Maria Lenk Aquatics Centre, Olympic Aquatics Stadium                                                                     2
# Olympic BMX Centre                                                                                                       2
# Beach Volleyball Arena                                                                                                   2
# Carioca Arena 1                                                                                                          1
# Carioca Arena 1, Youth Arena                                                                                             1
# Name: venues, dtype: int64

# %%
plt.figure(figsize=(12,15))
sns.countplot(y=data["venues"], color="lightblue")
plt.title("VENUES COUNT BAR CHART")

plt.show()

# %% [markdown]
# <b>Conclusion:</b>
# The "Olympics Staduim" has the highest occurence in the dataset appearing 46 times whereas the venue least appeared is "Caroica Arena".
