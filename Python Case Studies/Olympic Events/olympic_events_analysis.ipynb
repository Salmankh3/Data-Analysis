# %% [markdown]
# # OLYMPIC EVENTS DATA ANALYSIS & VISUALIZATIONS

# %% [markdown]
# ---------------

# %% [markdown]
# <b>LOADING DATASET</b>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("olympic_events.csv", encoding="ISO-8859-1")
data
# Out:
#          id          sport     discipline  \
# 0    701492       aquatics     backstroke
# 1    305278       aquatics     backstroke
# 2    708010       aquatics     backstroke
# 3    729643       aquatics     backstroke
# 4    567019       aquatics   breaststroke
# 5    607924       aquatics   breaststroke
# 6    519818       aquatics   breaststroke
# 7    778941       aquatics   breaststroke
# 8    795006       aquatics      butterfly
# 9     93436       aquatics      butterfly
# 10   649324       aquatics      butterfly
# 11   943021       aquatics      butterfly
# 12   772359       aquatics         diving
# 13   228171       aquatics         diving
# 14   305987       aquatics         diving
# 15   745896       aquatics         diving
# 16   574103       aquatics         diving
# 17    48684       aquatics         diving
# 18   524580       aquatics         diving
# 19   694510       aquatics         diving
# 20   760140       aquatics      freestyle
# 21   872869       aquatics      freestyle
# 22   789774       aquatics      freestyle
# 23   391049       aquatics      freestyle
# 24   568906       aquatics      freestyle
# 25   229032       aquatics      freestyle
# 26   121264       aquatics      freestyle
# 27    82103       aquatics      freestyle
# 28   338784       aquatics      freestyle
# 29   646337       aquatics      freestyle
# ..      ...            ...            ...
# 276  797257  weightlifting  weightlifting
# 277  512287  weightlifting  weightlifting
# 278  677718  weightlifting  weightlifting
# 279  417256  weightlifting  weightlifting
# 280  212799  weightlifting  weightlifting
# 281  902263  weightlifting  weightlifting
# 282  182568  weightlifting  weightlifting
# 283  273149  weightlifting  weightlifting
# 284  883392  weightlifting  weightlifting
# 285   82845  weightlifting  weightlifting
# 286  415046  weightlifting  weightlifting
# 287  747577  weightlifting  weightlifting
# 288  400419      wrestling      freestyle
# 289  212163      wrestling      freestyle
# 290  504233      wrestling      freestyle
# 291  848007      wrestling      freestyle
# 292  418998      wrestling      freestyle
# 293  588362      wrestling      freestyle
# 294  808414      wrestling      freestyle
# 295  834744      wrestling      freestyle
# 296  633484      wrestling      freestyle
# 297  525167      wrestling      freestyle
# 298  524420      wrestling      freestyle
# 299  716856      wrestling      freestyle
# 300  128413      wrestling    greco roman
# 301  755045      wrestling    greco roman
# 302  331407      wrestling    greco roman
# 303  169856      wrestling    greco roman
# 304  858736      wrestling    greco roman
# 305  767420      wrestling    greco roman
#
#                                     name     sex                      venues
# 0                Women's 100m Backstroke  female    Olympic Aquatics Stadium
# 1                Women's 200m Backstroke  female    Olympic Aquatics Stadium
# 2                  Men's 100m Backstroke    male    Olympic Aquatics Stadium
# 3                  Men's 200m Backstroke    male    Olympic Aquatics Stadium
# 4              Women's 100m Breaststroke  female    Olympic Aquatics Stadium
# 5              Women's 200m Breaststroke  female    Olympic Aquatics Stadium
# 6                Men's 100m Breaststroke    male    Olympic Aquatics Stadium
# 7                Men's 200m Breaststroke    male    Olympic Aquatics Stadium
# 8                 Women's 100m Butterfly  female    Olympic Aquatics Stadium
# 9                 Women's 200m Butterfly  female    Olympic Aquatics Stadium
# 10                  Men's 100m Butterfly    male    Olympic Aquatics Stadium
# 11                  Men's 200m Butterfly    male    Olympic Aquatics Stadium
# 12                  Women's 10m Platform  female  Maria Lenk Aquatics Centre
# 13                Women's 3m Springboard  female  Maria Lenk Aquatics Centre
# 14     Women's Synchronised 10m Platform  female  Maria Lenk Aquatics Centre
# 15   Women's Synchronised 3m Springboard  female  Maria Lenk Aquatics Centre
# 16                    Men's 10m Platform    male  Maria Lenk Aquatics Centre
# 17                  Men's 3m Springboard    male  Maria Lenk Aquatics Centre
# 18       Men's Synchronised 10m Platform    male  Maria Lenk Aquatics Centre
# 19     Men's Synchronised 3m Springboard    male  Maria Lenk Aquatics Centre
# 20                Women's 100m Freestyle  female    Olympic Aquatics Stadium
# 21                Women's 200m Freestyle  female    Olympic Aquatics Stadium
# 22      Women's 4 x 100m Freestyle Relay  female    Olympic Aquatics Stadium
# 23      Women's 4 x 200m Freestyle Relay  female    Olympic Aquatics Stadium
# 24                Women's 400m Freestyle  female    Olympic Aquatics Stadium
# 25                 Women's 50m Freestyle  female    Olympic Aquatics Stadium
# 26                Women's 800m Freestyle  female    Olympic Aquatics Stadium
# 27                  Men's 100m Freestyle    male    Olympic Aquatics Stadium
# 28                 Men's 1500m Freestyle    male    Olympic Aquatics Stadium
# 29                  Men's 200m Freestyle    male    Olympic Aquatics Stadium
# ..                                   ...     ...                         ...
# 276                         Women's 58kg  female      Riocentro - Pavilion 2
# 277                         Women's 63kg  female      Riocentro - Pavilion 2
# 278                         Women's 69kg  female      Riocentro - Pavilion 2
# 279                         Women's 75kg  female      Riocentro - Pavilion 2
# 280                         Men's +105kg    male      Riocentro - Pavilion 2
# 281                          Men's 105kg    male      Riocentro - Pavilion 2
# 282                           Men's 56kg    male      Riocentro - Pavilion 2
# 283                           Men's 62kg    male      Riocentro - Pavilion 2
# 284                           Men's 69kg    male      Riocentro - Pavilion 2
# 285                           Men's 77kg    male      Riocentro - Pavilion 2
# 286                           Men's 85kg    male      Riocentro - Pavilion 2
# 287                           Men's 94kg    male      Riocentro - Pavilion 2
# 288              Women's Freestyle 48 kg  female             Carioca Arena 2
# 289              Women's Freestyle 53 kg  female             Carioca Arena 2
# 290              Women's Freestyle 58 kg  female             Carioca Arena 2
# 291              Women's Freestyle 63 kg  female             Carioca Arena 2
# 292              Women's Freestyle 69 kg  female             Carioca Arena 2
# 293              Women's Freestyle 75 kg  female             Carioca Arena 2
# 294               Men's Freestyle 125 kg    male             Carioca Arena 2
# 295                Men's Freestyle 57 kg    male             Carioca Arena 2
# 296                Men's Freestyle 65 kg    male             Carioca Arena 2
# 297                Men's Freestyle 74 kg    male             Carioca Arena 2
# 298                Men's Freestyle 86 kg    male             Carioca Arena 2
# 299                Men's Freestyle 97 kg    male             Carioca Arena 2
# 300             Men's Greco-Roman 130 kg    male             Carioca Arena 2
# 301              Men's Greco-Roman 59 kg    male             Carioca Arena 2
# 302              Men's Greco-Roman 66 kg    male             Carioca Arena 2
# 303              Men's Greco-Roman 75 kg    male             Carioca Arena 2
# 304              Men's Greco-Roman 85 kg    male             Carioca Arena 2
# 305              Men's Greco-Roman 98 kg    male             Carioca Arena 2
#
# [306 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 6 columns):
# id            306 non-null int64
# sport         306 non-null object
# discipline    306 non-null object
# name          306 non-null object
# sex           306 non-null object
# venues        306 non-null object
# dtypes: int64(1), object(5)
# memory usage: 14.4+ KB

# %%
data.isna().sum()
# Out:
# id            0
# sport         0
# discipline    0
# name          0
# sex           0
# venues        0
# dtype: int64

# %%
data["id"].unique().size
# Out:
# 306

# %% [markdown]
# ----------

# %% [markdown]
# <b>ANALYZING ATTRIBUTES</b>

# %% [markdown]
# <b>Gender / Sex</b>

# %%
# COUNTS
data["sex"].value_counts()
# Out:
# male      161
# female    136
# mixed       9
# Name: sex, dtype: int64

# %%
# GENDER / SEX VISUALS

fig = plt.figure(figsize=(13,6))

fig.add_subplot(1,2,1)
plt.pie(data["sex"].value_counts(), autopct="%1.2f%%", labels=data["sex"].value_counts().index, startangle=180)
plt.title("GENDER COUNT PIE CHART")

fig.add_subplot(1,2,2)
sns.countplot(data["sex"])
plt.title("GENDER COUNT BAR CHART")

plt.show()

# %% [markdown]
# <b>Conclusions:</b>
# The highest occurence is of the male gender in the olympics event i.e. 52.6%, while female genders are 44.4%. There is also a mixed gender (paired participation) which seems to be only approximately 3%.

# %% [markdown]
# <b>Sport</b>

# %%
# COUNTS
data["sport"].value_counts()
# Out:
# athletics            47
# aquatics             46
# gymnastics           18
# wrestling            18
# cycling              18
# canoe                16
# shooting             15
# weightlifting        15
# rowing               14
# judo                 14
# boxing               13
# fencing              10
# sailing              10
# taekwondo             8
# equestrian            6
# tennis                5
# badminton             5
# volleyball            4
# table tennis          4
# archery               4
# golf                  2
# football              2
# hockey                2
# modern pentathlon     2
# handball              2
# triathlon             2
# rugby sevens          2
# basketball            2
# Name: sport, dtype: int64

# %%
# SPORT VISUALS

plt.figure(figsize=(13,13))

plt.pie(data["sport"].value_counts(), autopct="%1.1f%%", labels=data["sport"].value_counts().index, startangle=180)
plt.title("SPORT COUNT PIE CHART")

plt.show()

# %%
plt.figure(figsize=(13,10))

sns.countplot(y = data["sport"], orient="v", color="lightblue")
plt.title("SPORT COUNT BAR CHART")

plt.show()

# %% [markdown]
# <b>Conclusions:</b>
# Athletics came up with the highest occurence in our dataset (47 counts), while basketball, football, golf, hockey, handball, m.pentathlon, rugby, and triathlon have the least count (only 1).

# %% [markdown]
# <b>Discipline</b>

# %%
# COUNTS
data["discipline"].value_counts()
# Out:
# freestyle                26
# track                    24
# weightlifting            15
# shooting                 15
# artistic gymnastics      14
# judo                     14
# rowing                   14
# boxing                   13
# canoe sprint             12
# sailing                  10
# cycling track            10
# diving                    8
# throws                    8
# taekwondo                 8
# jumps                     8
# individual                6
# greco roman               6
# medley                    6
# road                      5
# tennis                    5
# badminton                 5
# cycling road              4
# archery                   4
# team                      4
# butterfly                 4
# canoe slalom              4
# breaststroke              4
# table tennis              4
# backstroke                4
# marathon swimming         2
# dressage                  2
# modern pentathlon         2
# synchronised swimming     2
# triathlon                 2
# handball                  2
# basketball                2
# cycling mountain bike     2
# rhythmic gymnastics       2
# cycling bmx               2
# rugby sevens              2
# golf                      2
# jumping                   2
# volleyball                2
# trampoline gymnastics     2
# football                  2
# eventing                  2
# hockey                    2
# water polo                2
# combined                  2
# beach volleyball          2
# Name: discipline, dtype: int64

# %%
fig = plt.figure(figsize=(13,13))

plt.pie(data["discipline"].value_counts(), autopct="%1.2f%%", labels=data["discipline"].value_counts().index, startangle=180)
plt.title("DISCIPLINE COUNT PIE CHART")
# Out:
# Text(0.5,1,'DISCIPLINE COUNT PIE CHART')

# %%
plt.figure(figsize=(12,12))
sns.countplot(y=data["discipline"], color="lightgreen")
plt.title("DISCIPLINE COUNT BAR CHART")

plt.show()
