# %% [markdown]
# # DATA CLEANING & PREPARATION OF FORBES RICHEST ATHLETES

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Forbes Richest Atheletes (Forbes Richest Athletes 1990-2019).csv')
data
# Out:
#      S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0       1         Mike Tyson         USA             1                NaN
# 1       2     Buster Douglas         USA             2                NaN
# 2       3  Sugar Ray Leonard         USA             3                NaN
# 3       4       Ayrton Senna      Brazil             4                NaN
# 4       5        Alain Prost      France             5                NaN
# ..    ...                ...         ...           ...                ...
# 286   287     Russell Wilson         USA             6                 ??
# 287   288       Aaron Rogers         USA             7                 ??
# 288   289       LeBron James         USA             8                  6
# 289   290      Stephen Curry         USA             9                  8
# 290   291       Kevin Durant         USA            10                 11
#
#                  Sport  Year  earnings ($ million)
# ...

# %%
del data['Previous Year Rank']

# %%
data
# Out:
#      S.NO               Name Nationality  Current Rank              Sport  \
# 0       1         Mike Tyson         USA             1             boxing
# 1       2     Buster Douglas         USA             2             boxing
# 2       3  Sugar Ray Leonard         USA             3             boxing
# 3       4       Ayrton Senna      Brazil             4        auto racing
# 4       5        Alain Prost      France             5        auto racing
# ..    ...                ...         ...           ...                ...
# 286   287     Russell Wilson         USA             6  American Football
# 287   288       Aaron Rogers         USA             7  American Football
# 288   289       LeBron James         USA             8         Basketball
# 289   290      Stephen Curry         USA             9         Basketball
# 290   291       Kevin Durant         USA            10         Basketball
#
#      Year  earnings ($ million)
# 0    1990                  28.6
# ...

# %%
data.Sport.unique()
# Out:
# array(['boxing', 'auto racing', 'golf', 'basketball', 'Basketball',
#        'Boxing', 'Auto Racing', 'Golf', 'Tennis', 'NFL', 'Auto racing',
#        'NBA', 'Baseball', 'Ice Hockey', 'American Football / Baseball',
#        'tennis', 'ice hockey', 'F1 Motorsports', 'NASCAR', 'Hockey',
#        'Auto Racing (Nascar)', 'F1 racing', 'American Football', 'soccer',
#        'baseball', 'cycling', 'motorcycle gp', 'Soccer', 'MMA'],
#       dtype=object)

# %%
dic_rep = {'boxing':'Boxing', 
           'auto racing':'NASCAR', 
           'Auto Racing':'NASCAR', 
           'Auto racing':'NASCAR', 
           'Auto Racing (Nascar)':'NASCAR', 
           'soccer':'Soccer', 
           'tennis':'Tennis', 
           'American Football / Baseball':'American Football', 
           'F1 racing':'F1 Motorsports',
           'golf':'Golf',
           'baseball':'Baseball',
           'motorcycle gp':'Moto GP',
           'basketball':'Basketball',
           'ice hockey':'Ice Hockey',
           'cycling':'Cycling'
          }

data['Sport'].replace(dic_rep, inplace=True)

# %%
data.Sport.unique()
# Out:
# array(['Boxing', 'NASCAR', 'Golf', 'Basketball', 'Tennis', 'NFL', 'NBA',
#        'Baseball', 'Ice Hockey', 'American Football', 'F1 Motorsports',
#        'Hockey', 'Soccer', 'Cycling', 'Moto GP', 'MMA'], dtype=object)

# %%
data.head(10)
# Out:
#    S.NO               Name Nationality  Current Rank       Sport  Year  \
# 0     1         Mike Tyson         USA             1      Boxing  1990
# 1     2     Buster Douglas         USA             2      Boxing  1990
# 2     3  Sugar Ray Leonard         USA             3      Boxing  1990
# 3     4       Ayrton Senna      Brazil             4      NASCAR  1990
# 4     5        Alain Prost      France             5      NASCAR  1990
# 5     6      Jack Nicklaus         USA             6        Golf  1990
# 6     7        Greg Norman   Australia             7        Golf  1990
# 7     8     Michael Jordan         USA             8  Basketball  1990
# 8     9      Arnold Palmer         USA             8        Golf  1990
# 9    10  Evander Holyfield         USA             8      Boxing  1990
#
#    earnings ($ million)
# 0                  28.6
# 1                  26.0
# 2                  13.0
# 3                  10.0
# 4                   9.0
# 5                   8.6
# ...

# %%
data.to_csv(r'E:/Backups/Datasets/Forbes Richest Athletes (Preprocessed Data).csv', index=False)
